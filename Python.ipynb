# %% [markdown]
# ## This guide ensures how we learn python from basics
# - what i found
# - what i use
# - what i need
# 1. import
# 2. from x to import y
# 3. use regular code
# 4. Funtions

# %% [markdown]
# # First we use imports and from xxx import yyy

# %%
import math # Imports the entire math module
from random import randint  # Only imports randint from random
from math import sqrt
import numpy as np

# %%
# Using math.sqrt to calculate the square root of 16
result = math.sqrt(16)
print(result)  # Output: 4.0
# Out:
# 4.0

# %%
# Directly using sqrt to calculate the square root of 16
result = sqrt(16)
print(result)  # Output: 4.0
# Out:
# 4.0

# %%
# Using numpy's array function

my_array = np.array([1, 2, 3])
print(my_array)  # Output: [1 2 3]
# Out:
# [1 2 3]

# %%
# Using math.pi
print("Pi:", math.pi)  # Output: 3.141592653589793
# Out:
# Pi: 3.141592653589793

# %%
# Using randint directly
print("Random integer:", randint(1, 10))  # Output: A random number between 1 and 10
# Out:
# Random integer: 9

# %% [markdown]
# # NOW WE USE FUNTIONS

# %%
# it dosen't give me an output right now
def greet():
    print("Hello, world!")

# %%
greet() #this function calls the previous code here:, and i will use it anytime anywhere in this notebook
# Out:
# Hello, world!

# %%
def greet(name): # One Argument calling
    print("Hello, " + name + "!")

# %%
greet("Alice")
# Out:
# Hello, Alice!

# %%
# Adding Multipule Arguments in One Function(fx)
def add_numbers(a, b):
    result = a + b
    print(result)

# %%
add_numbers(5, 10)
# Out:
# 15

# %%
# Return value instead of printing statements
def add_numbers(a, b):
    result = a + b
    return result

# %%
add_numbers(10, 8)
# Out:
# 18

# %%
sum_result = add_numbers(4, 16)
print(sum_result)
# Out:
# 20

# %%
# This is helpful because we can now use sum_result in other calculations:
double_sum = sum_result * 2
print(double_sum)
# Out:
# 40

# %%
# DEFAULT VALUES
def greet(name="Stranger"):
    print("Hello, " + name + "!")

# %%
greet()
# Out:
# Hello, Stranger!

# %%
greet("Yuvraj") # this will override previous value
# Out:
# Hello, Yuvraj!

# %% [markdown]
# ## Example: A Function with Multiple Arguments and Return Value
# Let’s create a function that calculates the area of a rectangle. It takes two arguments: width and height, and returns the area.

# %%
def calculate_area(width, height):
    area = width * height
    return area

# %% [markdown]
# *Now, I can use this function to calculate the area of different rectangles:*

# %%
area1 = calculate_area(5,10)
print("Area of Rectangle 1: ", area1)

area2 = calculate_area(3,4)
print("Area of Rectangle 2: ", area2)
# Out:
# Area of Rectangle 1:  50
# Area of Rectangle 2:  12

# %% [markdown]
# ### Summary
#
#
# * **Define** a function with def function_name():.
# * **Arguments** are inputs a function can accept.
# * **Return** values allow a function to give back a result.
# * **Default** arguments provide a fallback value if no argument is given.
#
# Functions make code reusable and efficient. I can use the same function with different arguments to get different results!

# %% [markdown]
# # Strings
# ## **1. Basic String Manipulation in Python**

# %%
text = "Hello, World!"
print(len(text)) # Outputs: 13/ it prints the lenght of every character and space between them in string
# Out:
# 13

# %%
greeting = "Hello, world!"
new_greeting = greeting.replace("world", "Python") # this replaces world with Python
print(new_greeting) # Output: "Hello, Python!"
# Out:
# Hello, Python!

# %%
messy_text = "   Hello, world!   "
clean_text = messy_text.strip() # removes any whitspaces from beginning and end from the string
print(messy_text) # Output: "   Hello, world!   "
print(clean_text)  # Output: "Hello, world!"
# Out:
#    Hello, world!
# Hello, world!

# %%
sentence="Hello, world Python is used for autonomouse agents or ai - agents development"
word=sentence.split()
print(word)
# Out:
# ['Hello,', 'world', 'Python', 'is', 'used', 'for', 'autonomouse', 'agents', 'or', 'ai', '-', 'agents', 'development']

# %%
words = ['Hello', 'world', 'Python', 'is', 'great']
sentence = " ".join(words)
print(sentence)  # Output: "Hello world Python is great"
# Out:
# Hello world Python is great

# %%
text = "Hello, world!"
print(text[0:5])   # Output: "Hello"
print(text[-6:])   # Output: "world!"
# Out:
# Hello
# world!

# %% [markdown]
# ## **2. Multi-line Strings**

# %%
# This prints as a single line, with no breaks, because the backslash \ tells Python to ignore the line break.

multi_line_string = "This is so long sentence in dictionery, \
but this is a small sentence" #this ensures there is no line break and merge all line breaks into one line
print(multi_line_string)
# Out:
# This is so long sentence in dictionery, but this is a small sentence

# %%
# Triple quotes allow for direct line breaks, and you can include both single (') and double (") quotes.

multi_line_quote = """This is a string
that contains multiple lines,
and we don't need to use a backslash.
It also handles quotes, like "this one" and 'that one'."""
print(multi_line_quote)
# Out:
# This is a string
# that contains multiple lines,
# and we don't need to use a backslash.
# It also handles quotes, like "this one" and 'that one'.

# %%
def greet(name):
    """
    This function takes a name as input and returns a greeting string.

    Parameters:
    name (str): The name of the person to greet.

    Returns:
    str: A greeting message.
    """
    return f"Hello, {name}!"

# Purpose: Docstrings serve as documentation for your code, helping others understand what the function does,
# what inputs it takes, and what output it produces.

# %%
greet("Priyanshu")
# Out:
# 'Hello, Priyanshu!'

# %% [markdown]
# # f-strings

# %% [markdown]
# **Basic f-string example**

# %%
name = "Yuvraj"
age = 18
message=f"Hello, My name is {name} and i am {age} years old."
print(message)
# Out:
# Hello, My name is Yuvraj and i am 18 years old.

# %% [markdown]
# **Example with Expressions**
#
# *You can even include expressions (like calculations) within the curly braces:*

# %%
widht = 5
height= 10
area_message = f"The area of a {widht}*{height} rectangle is {widht * height}."
print(area_message)
# Out:
# The area of a 5*10 rectangle is 50.

# %% [markdown]
# **Formatting Numbers**
#
# **Example with** :,.2f
# * **:** signals that you’re starting a format specification.
# * **,** adds comma separators for thousands.
# * **.2f** formats the number as a floating point with 2 decimal places.

# %%
price = 1234567.8910
formatted_price=f"The formatted price is {price:,.2f}"
print(formatted_price)
# Out:
# The formatted price is 1,234,567.89

# %% [markdown]
# **Formatting Dates**

# %%
from datetime import datetime

current_date = datetime.now()
formatted_date = f"Today’s date is {current_date:%B %d, %Y}."
print(f" Current date and time is {current_date}")
print(f""" Formatted date " {formatted_date}" """)
# Out:
#  Current date and time is 2026-06-02 21:00:21.297443
#  Formatted date " Today’s date is June 02, 2026."

# %% [markdown]
# Here’s what’s happening in **{current_date:%B %d, %Y}:**
#
# * **%B** represents the full month name (e.g., "November").
# * **%d** is the day of the month (with leading zero if necessary).
# * **%Y** is the four-digit year.
#
# *meaning if we add only %B, %d, %Y we add only year in formatted date and we regret time*

# %% [markdown]
# ### Summary of Common Formatting Options
#
# * ***{value:.2f}:*** Format as a float with 2 decimal places.
# * ***{value:,.2f}:*** Add commas as thousands separators, with 2 decimal places.
# * ***{date:%B %d, %Y}:*** Format a **datetime** object to display month, day, and year.
#
# With f-strings, you can format values right in the string, making your code cleaner and easier to read!

# %% [markdown]
# # Python lists, dicts and sets, including the *get()* method:
